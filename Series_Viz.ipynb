# %%
import altair as alt
import pandas as pd
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df = pd.read_csv('datasets/series.csv')

# %%
text = ' '.join(df['name'])

# %%
lemmatizer = WordNetLemmatizer()
porter = PorterStemmer()

# %%
def stemSentence(sentence):
    token_words=word_tokenize(sentence)
    stem_sentence=[]
    for word in token_words:
        word = lemmatizer.lemmatize(word)
        word = porter.stem(word)
        stem_sentence.append(word)
        stem_sentence.append(" ")
    return "".join(stem_sentence)

# %%
text = stemSentence(text)
# Out:
# 'moodi season aaa corpor bond yield rel to yield on 10-year treasuri constant matur import price index : asean - all commod moodi season baa corpor bond yield rel to yield on 10-year treasuri constant matur busi applic for the unit state busi applic for the unit state busi applic from corpor for the unit state busi applic from corpor for the unit state consum price index for all urban consum : purchas power of the consum dollar in u.s. citi averag china / u.s. foreign exchang rate japan / u.s. foreign exchang rate u.s. / euro foreign exchang rate u.s. / u.k. foreign exchang rate 10-year treasuri inflation-index secur , constant matur 20-year treasuri inflation-index secur , constant matur 30-year treasuri inflation-index secur , constant matur 5-year treasuri inflation-index secur , constant matur 7-year treasuri inflation-index secur , constant matur treasuri inflation-index long-term averag yield primari credit rate bank prime loan rate import price index : european union - all commod effect feder fund rate effect feder fund volum cass freight index : shipment gross valu weight industri product : final product gross valu weight industri product : final product and nonindustri suppli gross valu weight industri product : consum good gross valu weight industri product : durabl consum good gross valu weight industri product : automot product gross valu weight industri product : other durabl good gross valu weight industri product : nondur consum good gross valu weight industri product : equip , total gross valu weight industri product : busi equip gross valu weight industri product : busi equip and defens and space equip gross valu weight industri product : defens and space equip gross valu weight industri product : nonindustri suppli gross valu weight industri product : construct suppli gross valu weight industri product : busi suppli gross valu weight industri product : commerci energi product equiti market volatil : infecti diseas tracker interest rate on excess reserv interest rate on requir reserv median consum price index 15-year fix rate mortgag averag in the unit state 30-year fix rate mortgag averag in the unit state overnight bank fund rate overnight bank fund volum produc price index by industri : deliveri and warehous industri produc price index by industri : inform produc price index by industri : total mine , util , and manufactur industri produc price index by industri : total retail trade industri produc price index by industri : select health care industri produc price index by industri : other select servic less trade , transport , and wareh industri produc price index by industri : total trade industri produc price index by industri : transport industri produc price index by industri : transport and wareh industri produc price index by industri : servic less trade , transport , and wareh produc price index by industri : total wholesal trade industri produc price index by industri : total manufactur industri produc price index by industri : total mine industri san francisco tech puls secur overnight financ rate secur overnight financ volum S & P 500 10-year breakeven inflat rate ted spread total asset , all commerci bank total liabil , all commerci bank freight transport servic index unemploy rate equiti market-rel econom uncertainti index '

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color="white", width=800, height=400).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
stemmer.stem('industrial')
# Out:
# 'industrial'

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
text = lemmatizer.lemmatize(text)
stemmer.stem(text)
# Out:
# 'moodys seasoned aaa corporate bond yield relative to yield on 10-year treasury constant maturity import price index: asean - all commodities moodys seasoned baa corporate bond yield relative to yield on 10-year treasury constant maturity business applications for the united states business applications for the united states business applications from corporations for the united states business applications from corporations for the united states consumer price index for all urban consumers: purchasing power of the consumer dollar in u.s. city average china / u.s. foreign exchange rate japan / u.s. foreign exchange rate u.s. / euro foreign exchange rate u.s. / u.k. foreign exchange rate 10-year treasury inflation-indexed security, constant maturity 20-year treasury inflation-indexed security, constant maturity 30-year treasury inflation-indexed security, constant maturity 5-year treasury inflation-indexed security, constant maturity 7-year treasury inflation-indexed security, constant maturity treasury inflation-indexed long-term average yield primary credit rate bank prime loan rate import price index: european union - all commodities effective federal funds rate effective federal funds volume cass freight index: shipments gross value weighted industrial production: final products gross value weighted industrial production: final products and nonindustrial supplies gross value weighted industrial production: consumer goods gross value weighted industrial production: durable consumer goods gross value weighted industrial production: automotive products gross value weighted industrial production: other durable goods gross value weighted industrial production: nondurable consumer goods gross value weighted industrial production: equipment, total gross value weighted industrial production: business equipment gross value weighted industrial production: business equipment and defense and space equipment gross value weighted industrial production: defense and space equipment gross value weighted industrial production: nonindustrial supplies gross value weighted industrial production: construction supplies gross value weighted industrial production: business supplies gross value weighted industrial production: commercial energy products equity market volatility: infectious disease tracker interest rate on excess reserves interest rate on required reserves median consumer price index 15-year fixed rate mortgage average in the united states 30-year fixed rate mortgage average in the united states overnight bank funding rate overnight bank funding volume producer price index by industry: delivery and warehouse industries producer price index by industry: information producer price index by industry: total mining, utilities, and manufacturing industries producer price index by industry: total retail trade industries producer price index by industry: selected health care industries producer price index by industry: other selected services less trade, transportation, and warehousing industries producer price index by industry: total trade industries producer price index by industry: transportation industries producer price index by industry: transportation and warehousing industries producer price index by industry: services less trade, transportation, and warehousing producer price index by industry: total wholesale trade industries producer price index by industry: total manufacturing industries producer price index by industry: total mining industries san francisco tech pulse secured overnight financing rate secured overnight financing volume s&p 500 10-year breakeven inflation rate ted spread total assets, all commercial banks total liabilities, all commercial banks freight transportation services index unemployment rate equity market-related economic uncertainty index'

# %%
source = df

bars = alt.Chart(source).mark_bar().encode(
    x='',
    y="year:O"
)
